# %%
# plot
using Plots

# %%
gr()  # バックエンドをGRで指定
# Out:
# Plots.GRBackend()

# %%
x = 1:100;

# %%
y = rand(100, 1);  # 乱数を生成

# %%
plot(x, y)

# %%
plot(x, y, title= " TwoLines", label=["Line 1" "Line2"], lw = 3)

# %%
xlabel!("My x label"); ylabel!("My y label")

# %%
markershapes = [:circle :diamond];

# %%
markercolors = [:red :blue];

# %%
plot(x, y,
    title="Myplot",
    xlabel="My x label",
    ylabel="My y label",
    label=["1", "2"],
    color= markercolors,
    shape= markershapes,
    annotation = [(2, .3, "Annotation!!!")])

# %%
plot(sin)  # sin

# %%
plot!(cos)  # 上書き

# %%
# 散布図
x=rand(100)
y=rand(100)
plot(x, y, seriestype= :scatter, legend = false, color=[:red])
# Out:
# ┌ Warning: Indices Base.OneTo(1) of attribute `seriescolor` does not match data indices 1:100.
# └ @ Plots /home/nk/.julia/packages/Plots/5kcBO/src/utils.jl:129
# ┌ Warning: Indices Base.OneTo(1) of attribute `linecolor` does not match data indices 1:100.
# └ @ Plots /home/nk/.julia/packages/Plots/5kcBO/src/utils.jl:129
# ┌ Warning: Indices Base.OneTo(1) of attribute `fillcolor` does not match data indices 1:100.
# └ @ Plots /home/nk/.julia/packages/Plots/5kcBO/src/utils.jl:129
# ┌ Warning: Indices Base.OneTo(1) of attribute `markercolor` does not match data indices 1:100.
# └ @ Plots /home/nk/.julia/packages/Plots/5kcBO/src/utils.jl:129
# ┌ Warning: Indices Base.OneTo(1) of attribute `seriescolor` does not match data indices 1:100.
# └ @ Plots /home/nk/.julia/packages/Plots/5kcBO/src/utils.jl:129
# ┌ Warning: Indices Base.OneTo(1) of attribute `linecolor` does not match data indices 1:100.
# └ @ Plots /home/nk/.julia/packages/Plots/5kcBO/src/utils.jl:129
# ...

# %%
# bar chart
plot(x, y, st= :bar, legend = false)

# %%
plot(x, y, seriestype= :histogram, legend=false)

# %%
# 複数グラフ
using Plots

# %%
x = 1:10
# Out:
# 1:10

# %%
y = randn(10, 5)
# Out:
# 10×5 Matrix{Float64}:
#   0.0660786   0.446028   -1.78428    2.35749   -0.784782
#  -0.692754    0.157185    1.42801   -0.999238  -0.149855
#  -2.1202     -1.4976     -0.510283   1.23153   -0.2177
#   0.377478    1.02781     1.96673   -1.57597   -0.590884
#  -0.0558121   1.0532     -0.506317  -0.235743  -1.27558
#   0.355689   -1.40888    -0.987614   0.496801  -1.65464
#   1.58123    -0.26795     0.220974  -0.45798    1.20178
#  -0.408309   -0.0839205   0.104162   0.537533   0.141482
#  -0.0762574  -0.0225923  -0.721559   0.664209  -0.512849
#   0.435455    2.30029    -1.63385    0.262048  -1.77348

# %%
plot(x, y, layout=(5, 1))  # 5つのグラフを並べる

# %%
plot(scatter(x, y),
    plot(x, y),
    histogram(x, y),
    plot(x, y, lw=3, title="Title"),
    layout=(2, 2), legend=false)

# %%
# Sklearn
using ScikitLearn

# %%
# データ・セット
# iris
using RDatasets: dataset

# %%
iris = dataset("datasets", "iris")
# Out:
# 150×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼─────────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa
#    2 │         4.9         3.0          1.4         0.2  setosa
#    3 │         4.7         3.2          1.3         0.2  setosa
#    4 │         4.6         3.1          1.5         0.2  setosa
#    5 │         5.0         3.6          1.4         0.2  setosa
#    6 │         5.4         3.9          1.7         0.4  setosa
#    7 │         4.6         3.4          1.4         0.3  setosa
#    8 │         5.0         3.4          1.5         0.2  setosa
#    9 │         4.4         2.9          1.4         0.2  setosa
#   10 │         4.9         3.1          1.5         0.1  setosa
#   11 │         5.4         3.7          1.5         0.2  setosa
# ...

# %%
# 概要確認
first(iris, 5)
# Out:
# 5×5 DataFrame
#  Row │ SepalLength  SepalWidth  PetalLength  PetalWidth  Species
#      │ Float64      Float64     Float64      Float64     Cat…
# ─────┼───────────────────────────────────────────────────────────
#    1 │         5.1         3.5          1.4         0.2  setosa
#    2 │         4.9         3.0          1.4         0.2  setosa
#    3 │         4.7         3.2          1.3         0.2  setosa
#    4 │         4.6         3.1          1.5         0.2  setosa
#    5 │         5.0         3.6          1.4         0.2  setosa

# %%
using DataFrames
X = convert(Array, iris[[:SepalLength, :SepalWidth, :PetalLength, :PetalWidth]])
y = convert(Array, iris[:Species])
# Out:
# MethodError: no method matching getindex(::DataFrame, ::Vector{Symbol})
# Closest candidates are:
#   getindex(::DataFrame, ::AbstractVector{T}, ::Colon) where T at /home/nk/.julia/packages/DataFrames/vuMM8/src/dataframe/dataframe.jl:563
#   getindex(::DataFrame, ::AbstractVector{T}, ::Union{Colon, Regex, AbstractVector{T} where T, All, Between, Cols, InvertedIndex}) where T at /home/nk/.julia/packages/DataFrames/vuMM8/src/dataframe/dataframe.jl:540
#   getindex(::DataFrame, ::AbstractVector{T} where T, ::Union{AbstractString, Signed, Symbol, Unsigned}) at /home/nk/.julia/packages/DataFrames/vuMM8/src/dataframe/dataframe.jl:486
#   ...
#
# Stacktrace:
#  [1] top-level scope
#    @ In[25]:2
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
# y = convert(Array, iris[:String, 1]);
# Out:
# MethodError: no method matching getindex(::DataFrame, ::Symbol, ::Int64)
# Closest candidates are:
#   getindex(::DataFrame, ::typeof(!), ::Union{Signed, Unsigned}) at /home/nk/.julia/packages/DataFrames/vuMM8/src/dataframe/dataframe.jl:504
#   getindex(::DataFrame, ::Colon, ::Union{AbstractString, Signed, Symbol, Unsigned}) at /home/nk/.julia/packages/DataFrames/vuMM8/src/dataframe/dataframe.jl:498
#   getindex(::DataFrame, ::InvertedIndex, ::Union{AbstractString, Signed, Symbol, Unsigned}) at /home/nk/.julia/packages/DataFrames/vuMM8/src/dataframe/dataframe.jl:494
#   ...
#
# Stacktrace:
#  [1] top-level scope
#    @ In[26]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
y
# Out:
# 10×5 Matrix{Float64}:
#   0.0660786   0.446028   -1.78428    2.35749   -0.784782
#  -0.692754    0.157185    1.42801   -0.999238  -0.149855
#  -2.1202     -1.4976     -0.510283   1.23153   -0.2177
#   0.377478    1.02781     1.96673   -1.57597   -0.590884
#  -0.0558121   1.0532     -0.506317  -0.235743  -1.27558
#   0.355689   -1.40888    -0.987614   0.496801  -1.65464
#   1.58123    -0.26795     0.220974  -0.45798    1.20178
#  -0.408309   -0.0839205   0.104162   0.537533   0.141482
#  -0.0762574  -0.0225923  -0.721559   0.664209  -0.512849
#   0.435455    2.30029    -1.63385    0.262048  -1.77348

# %%
convert(Array, iris[:SepalLength])
# Out:
# ArgumentError: syntax df[column] is not supported use df[!, column] instead
#
# Stacktrace:
#  [1] getindex(#unused#::DataFrame, #unused#::Symbol)
#    @ DataFrames ~/.julia/packages/DataFrames/vuMM8/src/abstractdataframe/abstractdataframe.jl:2161
#  [2] top-level scope
#    @ In[28]:1
#  [3] eval
#    @ ./boot.jl:360 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
# Sklearn
using PyCall
using ScikitLearn
@sk_import linear_model : LogisticRegression
# @sk_import tree : DecisionTreeClassifier
# @sk_import ensemble : RandomForestClassifier
# @sk_import model_selection : train_test_split
# @sk_import metrics : accuracy_score
# Out:
# PyObject <class 'sklearn.linear_model._logistic.LogisticRegression'>

# %%
@sk_import linear_model: LogisticRegression
# Out:
# WARNING: redefinition of constant LogisticRegression. This may fail, cause incorrect answers, or produce other errors.
# PyObject <class 'sklearn.linear_model._logistic.LogisticRegression'>

# %%
using MLJ
